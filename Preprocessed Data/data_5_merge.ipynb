# %% [markdown]
# ### Data-5

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
data_5 = pd.read_csv('../DataSet/Screening/Screening question/Autism_Data.arff')
data_5
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ... gender       ethnicity jundice austim  \
# ...

# %%
data_5['relation'].unique()
# Out:
# array(['Self', 'Parent', '?', "'Health care professional'", 'Relative',
#        'Others'], dtype=object)

# %%
data_5['age'].unique()
# Out:
# array(['26', '24', '27', '35', '40', '36', '17', '64', '29', '33', '18',
#        '31', '30', '34', '38', '42', '43', '48', '37', '55', '50', '53',
#        '20', '28', '21', '383', '47', '32', '44', '?', '19', '58', '45',
#        '22', '39', '25', '23', '54', '60', '41', '46', '56', '61', '59',
#        '52', '49', '51'], dtype=object)

# %%
data_5['ethnicity'].unique()
# Out:
# array(['White-European', 'Latino', '?', 'Others', 'Black', 'Asian',
#        "'Middle Eastern '", 'Pasifika', "'South Asian'", 'Hispanic',
#        'Turkish', 'others'], dtype=object)

# %% [markdown]
# #### Converting binary categorial variable to numerical variables

# %%
data_5['gender'].replace(['f','m'], [0,1] ,inplace=True)
data_5['jundice'].replace(['no','yes'], [0,1] ,inplace=True)
data_5['austim'].replace(['no','yes'], [0,1] ,inplace=True)
data_5['used_app_before'].replace(['no','yes'], [0,1] ,inplace=True)
data_5['Class/ASD'].replace(['NO','YES'], [0,1] ,inplace=True)

# %%
data_5
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ... gender       ethnicity jundice  \
# ...

# %%
print("Counting ? values\n")
print(data_5.isin(['?']).sum(axis=0))
# Out:
# Counting ? values
#
# A1_Score            0
# A2_Score            0
# A3_Score            0
# A4_Score            0
# A5_Score            0
# A6_Score            0
# A7_Score            0
# A8_Score            0
# A9_Score            0
# A10_Score           0
# age                 2
# gender              0
# ethnicity          95
# jundice             0
# austim              0
# contry_of_res       0
# used_app_before     0
# result              0
# age_desc            0
# relation           95
# Class/ASD           0
# dtype: int64

# %% [markdown]
# #### Filling missing values

# %%
data_5["age"].mode()
# Out:
# 0    21
# dtype: object

# %%
data_5['relation'].mode()
# Out:
# 0    Self
# dtype: object

# %%
data_5['ethnicity'].mode()
# Out:
# 0    White-European
# dtype: object

# %%
data_5['ethnicity'] = data_5['ethnicity'].replace('?','White-European')
data_5['relation'] = data_5['relation'].replace('?','Self')
data_5['age'] = data_5['age'].replace('?','21')

# %%
data_5['relation'].unique()
# Out:
# array(['Self', 'Parent', "'Health care professional'", 'Relative',
#        'Others'], dtype=object)

# %%
data_5['age'].unique()
# Out:
# array(['26', '24', '27', '35', '40', '36', '17', '64', '29', '33', '18',
#        '31', '30', '34', '38', '42', '43', '48', '37', '55', '50', '53',
#        '20', '28', '21', '383', '47', '32', '44', '19', '58', '45', '22',
#        '39', '25', '23', '54', '60', '41', '46', '56', '61', '59', '52',
#        '49', '51'], dtype=object)

# %%
data_5['ethnicity'].unique()
# Out:
# array(['White-European', 'Latino', 'Others', 'Black', 'Asian',
#        "'Middle Eastern '", 'Pasifika', "'South Asian'", 'Hispanic',
#        'Turkish', 'others'], dtype=object)

# %%
data_5.columns[data_5.isna().any()].tolist()
# Out:
# []

# %%
print(data_5.isnull().any().any())
print(data_5.isnull().sum().sum())
# Out:
# False
# 0

# %% [markdown]
# #### DataFrame to CSV

# %%
data_5.to_csv('../DataSet/Screening/Screening question/new_Autism_Data.csv')
